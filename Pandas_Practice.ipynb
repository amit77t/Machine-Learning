# %% [markdown]
# <a href="https://colab.research.google.com/github/amit77t/Machine-Learning/blob/main/Pandas_Practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
print(f"pandas version: {pd.__version__}")
# Out:
# pandas version: 2.1.4

# %%
# Datatype

# %%
animals=pd.Series(["cat", "dog","cow","lion","tiger"])
animals
# Out:
# 0      cat
# 1      dog
# 2      cow
# 3     lion
# 4    tiger
# dtype: object

# %%
days=pd.Series(["Monday", "Tuesday", "Wednesday","Thursday","friday","Saturday","Sunday"])
days
# Out:
# 0       Monday
# 1      Tuesday
# 2    Wednesday
# 3     Thursday
# 4       friday
# 5     Saturday
# 6       Sunday
# dtype: object

# %%
random_data=pd.DataFrame({"Animals names": animals,
                          "Days in week": days})
random_data
# Out:
#   Animals names Days in week
# 0           cat       Monday
# 1           dog      Tuesday
# 2           cow    Wednesday
# 3          lion     Thursday
# 4         tiger       friday
# 5           NaN     Saturday
# 6           NaN       Sunday

# %%
Electronics=pd.Series(["Laptop","Mobile","Earbuds","Speaker","Headphone"])

# %%
Electronics
# Out:
# 0       Laptop
# 1       Mobile
# 2      Earbuds
# 3      Speaker
# 4    Headphone
# dtype: object

# %%
Price=pd.Series(["35000","20000","1500","2050","5000"])
Price
# Out:
# 0    35000
# 1    20000
# 2     1500
# 3     2050
# 4     5000
# dtype: object

# %%
Gadgets=pd.DataFrame({"Electronics items":Electronics,
                      "Price of items":Price})
Gadgets
# Out:
#   Electronics items Price of items
# 0            Laptop          35000
# 1            Mobile          20000
# 2           Earbuds           1500
# 3           Speaker           2050
# 4         Headphone           5000

# %%
# importing csv files

# %%
car_sales=pd.read_csv("car-sales.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
car_sales.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
car_sales.mean(numeric_only=True)
# Out:
# Odometer (KM)    78601.4
# Doors                4.0
# dtype: float64

# %%
numbers=pd.Series([1,2,3,4,5,5,6,7,8,9])
numbers.mean()
# Out:
# 5.0

# %%
numbers.sum()
# Out:
# 50

# %%
car_sales.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_cloumns= car_sales.columns
car_cloumns[0]
# Out:
# 'Make'

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.iloc[7]
# Out:
# Make                 Honda
# Colour                Blue
# Odometer (KM)        54738
# Doors                    4
# Price            $7,000.00
# Name: 7, dtype: object

# %%
car_sales.loc[2]
# Out:
# Make                Toyota
# Colour                Blue
# Odometer (KM)        32549
# Doors                    3
# Price            $7,000.00
# Name: 2, dtype: object

# %%
colors=pd.Series(["red", "blue","pink","yellow","green","orange","white"],index=[0,3,9,8,67,3,23])
colors
# Out:
# 0        red
# 3       blue
# 9       pink
# 8     yellow
# 67     green
# 3     orange
# 23     white
# dtype: object

# %%
colors.loc[3]
# Out:
# 3      blue
# 3    orange
# dtype: object

# %%
colors.loc[9]
# Out:
# 'pink'

# %%
colors.loc[0]
# Out:
# 'red'

# %%
colors.loc[8]
# Out:
# 'yellow'

# %%
colors.iloc[3]
# Out:
# 'yellow'

# %%
car_sales["Make"]
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sales["Colour"]
# Out:
# 0    White
# 1      Red
# 2     Blue
# 3    Black
# 4    White
# 5    Green
# 6     Blue
# 7     Blue
# 8    White
# 9    White
# Name: Colour, dtype: object

# %%
car_sales[car_sales["Make"]=="Toyota"]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 2  Toyota   Blue          32549      3  $7,000.00
# 5  Toyota  Green          99213      4  $4,500.00
# 8  Toyota  White          60000      4  $6,250.00

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

car_sales["Odometer (KM)"].plot()
# Out:
# <Axes: >

# %%
car_sales.plot(x="Make",y="Odometer (KM)")
# Out:
# <Axes: xlabel='Make'>

# %%
car_sales["Odometer (KM)"].hist()
# Out:
# <Axes: >

# %%
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 528.0+ bytes

# %%
# Change Price column to integers
car_sales["Price"] = car_sales["Price"].str.replace('[\$\,\.]', '', regex=True)
car_sales
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-56-bdb6a62bd3d7> in <cell line: 2>()
#       1 # Change Price column to integers
# ----> 2 car_sales["Price"] = car_sales["Price"].str.replace('[\$\,\.]', '', regex=True)
#       3 car_sales
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#    6205
#    6206     @final
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     222             # we're accessing the attribute of the class, i.e., Dataset.geo
#     223             return self._accessor
# --> 224         accessor_obj = self._accessor(obj)
#     225         # Replace the property with the accessor object. Inspired by:
# ...

# %%
# Remove 2 extra zeros from the price column (2200000 -> 22000) by indexing all but the last two digits
car_sales["Price"] = car_sales["Price"].str[:-2].astype(int)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
## Manipulating data with python

car_sales["Make"].str.lower()
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: object
